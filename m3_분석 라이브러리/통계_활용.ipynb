# %% [markdown]
# Q. 한 학급의 학생 10명의 수학 시험 점수는 다음과 같습니다:
#
# [85, 72, 90, 68, 88, 76, 95, 89, 77, 84].
#
# 학급의 평균 점수와 표준편차를 계산하여 전체 성적 수준과 변동성을 파악하세요. 이 데이터에서 어떤 인사이트를 얻을 수 있습니까?

# %%
import pandas as pd
import numpy as np
data = [85, 72, 90, 68, 88, 76, 95, 89, 77, 84]
data_mean = np.mean(data)
data_std = np.std(data)
print(data_mean,'\n')
print(data_std)

# 인사이트 해석
# 평균은 학급의 전체 성적수준을 나타내고, 표준편차는 성적의 변동성을 나타냅니다

if data_std > 10:
    print("성적 변동성이 큽니다")
else:
    print("성적 변동성이 작습니다")
# Out:
# 82.4
#
# 8.284926070883191
# 성적 변동성이 작습니다

# %% [markdown]
# Q. 어느 도시에 지난 1년간 매달 내린 강수량 데이터는 다음과 같습니다:
#
# [85, 90, 78, 110, 88, 76, 120, 89, 77, 91, 100, 95].
#
# 이 데이터를 이용해 중간값과 1사분위수, 3사분위수를 계산하여 강수량의 분포를 파악하세요. 이 데이터에서 어떤 인사이트를 얻을 수 있습니까?

# %%
data = [85, 90, 78, 110, 88, 76, 120, 89, 77, 91, 100, 95]

df = pd.DataFrame(data)
print(df.describe(),'\n')

print(df.quantile(.25))
print(df.quantile(.75))
# Out:
#                 0
# count   12.000000
# mean    91.583333
# std     13.262787
# min     76.000000
# 25%     83.250000
# 50%     89.500000
# 75%     96.250000
# max    120.000000
#
# 0    83.25
# Name: 0.25, dtype: float64
# 0    96.25
# Name: 0.75, dtype: float64

# %%
rainfall = [85, 90, 78, 110, 88, 76, 120, 89, 77, 91, 100, 95]

# 중간값 및 사분위수 계산

median = np.median(rainfall)
q1 = np.percentile(rainfall, 25)
q3 = np.percentile(rainfall, 75)

print(f"median: {median}, Q1: {q1}, Q3: {q3}" )

# 중간값은 전체 강수량 분포의 중심을 나타내고 사분위수는 데이터의 분포범위를 나타냄
print(f"강수량의 중앙값은 {median} mm이며 이는 일반적인 강수량 수준을 나타냄")
print(f"1사분위수와 3사분위 수의 차이는 {q3 - q1} mm이며 이는 강수량의 변동성을 보여줌")
# Out:
# median: 89.5, Q1: 83.25, Q3: 96.25
# 강수량의 중앙값은 89.5 mm이며 이는 일반적인 강수량 수준을 나타냄
# 1사분위수와 3사분위 수의 차이는 13.0 mm이며 이는 강수량의 변동성을 보여줌

# %% [markdown]
# Q. 한 온라인 쇼핑몰의 지난 10일간 일일 방문자 수는 다음과 같습니다:
#
# [150, 200, 220, 180, 190, 170, 210, 230, 160, 175].
#
# 방문자 수의 분포를 시각화하기 위해 히스토그램을 그리고, 방문자 수의 변동성에 대한 인사이트를 도출하세요.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = [150, 200, 220, 180, 190, 170, 210, 230, 160, 175]

df = pd.DataFrame(data)

#df.plot.hist()

# %%
visitors = np.array([150, 200, 220, 180, 190, 170, 210, 230, 160, 175])

plt.hist(visitors, bins = 5, edgecolor = 'black')
plt.title('Histogram of Daily Visitors')
plt.xlabel('Number of Visitors')
plt.ylabel('Frequency')
plt.show()

# 히스토그램을 통해 방문자 수의 분포를 시각화
mean_visitors = np.mean(visitors)
std_dev_visitors = np.std(visitors)

print(f"Mean: {mean_visitors}, standard deviation : {std_dev_visitors}")
if std_dev_visitors > 20:
    print("방문자 수의 변동성이 크다")
else:
    print("방문자 수의 변동성이 작다")
# Out:
# Mean: 188.5, standard deviation : 24.904818810824544
# 방문자 수의 변동성이 크다

# %% [markdown]
# Q. 한 회사의 직원 연봉 데이터가 다음과 같습니다:
#
# [45000, 50000, 52000, 47000, 48000, 53000, 60000, 62000, 55000, 58000].
#
# 이 데이터를 이용하여 연봉의 분포와 이상치를 시각화하는 상자 그림을 그리고, 연봉 분포에 대한 인사이트를 도출하세요.

# %%
data = [45000, 50000, 52000, 47000, 48000, 53000, 60000, 62000, 55000, 58000]

salaries = np.array([45000, 50000, 52000, 47000, 48000, 53000, 60000, 62000, 55000, 58000])

plt.boxplot(salaries)
plt.title('Box Plot of Employee Salaries')
plt.ylabel('Salaries')
plt.show()

median_salary = np.median(salaries)
q1_salary = np.percentile(salaries,25)
q3_salary = np.percentile(salaries,75)
iqr_salary = q3_salary - q1_salary

print(f"Median Salary: {median_salary}")
print(f"Q1: {q1_salary}, Q3: {q3_salary}, IQR: {iqr_salary}")

# 이상치 확인
lower_bound = q1_salary - 1.5 * iqr_salary
upper_bound = q3_salary + 1.5 * iqr_salary
outliers = salaries[(salaries < lower_bound) | (salaries > upper_bound)]
print(f"Outliers: {outliers}")
# Out:
# Median Salary: 52500.0
# Q1: 48500.0, Q3: 57250.0, IQR: 8750.0
# Outliers: []

# %% [markdown]
# Q. 한 마케팅 캠페인에서 투자한 광고비와 발생한 매출 데이터가 각각 다음과 같습니다:
#
# 광고비 [1, 2, 3, 4, 5] (단위: 천 달러),
#
# 매출 [10, 15, 20, 25, 30] (단위: 천 달러).
#
# 광고비와 매출 간의 관계를 시각화하기 위해 산점도를 그리고, 두 변수 간의 관계에 대한 인사이트를 도출하세요.

# %%
ad_spend = np.array([1, 2, 3, 4, 5] )
sales = ad_spend + np.random.randint(10, size = 5)

plt.scatter(ad_spend,sales)
plt.title('Scatter Plot of Ad Spend vs Sales')
plt.xlabel('Ad Spend (thousnad dollars)')
plt.ylabel('Sales (thousand dollars)')
plt.show()

correlation = np.corrcoef(ad_spend, sales)[0,1]
print(f"Correlation coefficient: {correlation}")

if correlation > 0.7:
    print("광고비와 매출간에 강한 양의 상관관계")
else:
    print("광고비와 매출간에 상관관계가 약하거나 없다")
# Out:
# Correlation coefficient: 0.38417490996391623
# 광고비와 매출간에 상관관계가 약하거나 없다

# %% [markdown]
# Q. 한 식당의 월별 홍보 비용과 월별 방문자 수 데이터가 각각 다음과 같습니다:
#
# 홍보 비용 [500, 600, 700, 800, 900] (단위: 달러),
#
# 방문자 수 [300, 400, 500, 600, 700] (단위: 명).
#
# 홍보 비용과 방문자 수 간의 상관 계수를 계산하여 관계를 파악하세요. 이 데이터에서 어떤 인사이트를 얻을 수 있습니까?

# %%
x = np.array([500, 600, 700, 800, 900])
y = np.array([300, 400, 500, 600, 700])
vy = np.sort(y)[::-1]

# 상관계수 계산
correlation = np.corrcoef(x,vy)[0,1]
print(f"Correlation coefficient: {correlation}")

if correlation > 0.7:
    print("홍보 비용과 방문자 수 간에 강한 양의 상관관계가 있다")
elif correlation < 0.7:
    print("홍보 비용과 방문자 수 간에 강한 음의 상관관계가 있다")
else:
    print("홍보 비용과 방문자 수 간에 상관관계가 약하거나 없다")
# Out:
# Correlation coefficient: -0.9999999999999998
# 홍보 비용과 방문자 수 간에 강한 음의 상관관계가 있다

# %% [markdown]
# Q. 세 종류의 화합물에 대한 실험 데이터를 다음 매트릭스로 나타냅니다:
#
# [[1, 2, 3], [2, 4, 6], [3, 6, 9]].
#
# 이 매트릭스의 히트맵을 그려 데이터 간의 관계를 시각화하고, 인사이트를 도출하세요.

# %%
import seaborn as sns

data = np.array([[1, 2, 3], [2, 4, 6], [3, 6, 9]])

sns.heatmap(data, annot = True ,cmap = 'coolwarm', xticklabels = ['A','B','C'], yticklabels = ['A','B','C'])
plt.title('Heatmap of Chemical Compounds A, B, C')
plt.show()

print("인사이트")
print("1. 데이터가 대각선 방향으로 커지는 패턴을 보인다. 이는 각 화합물의 농도가 일정한 비율로 증가하고 있음을 나타냄")
print("2. 각 행과 열의 값들이 비례적으로 증가하여 화합물 간의 반응이 선형적인 관계를 가질 수 있음을 시사")
# Out:
# 인사이트
# 1. 데이터가 대각선 방향으로 커지는 패턴을 보인다. 이는 각 화합물의 농도가 일정한 비율로 증가하고 있음을 나타냄
# 2. 각 행과 열의 값들이 비례적으로 증가하여 화합물 간의 반응이 선형적인 관계를 가질 수 있음을 시사

# %% [markdown]
# Q. 한 지역의 주택 가격 데이터가 다음과 같습니다:
#
# [250000, 300000, 350000, 400000, 450000, 500000, 550000, 600000, 650000, 700000].
#
# 주택 가격의 분포를 시각화하기 위해 분포 그래프를 그리고, 주택 가격 분포에 대한 인사이트를 도출하세요.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


price = np.array([250000, 300000, 350000, 400000, 450000, 500000, 550000, 600000, 650000, 700000])

sns.kdeplot(price, fill = True)
plt.title('Density Plot of House Peices')
plt.xlabel('Price')
plt.ylabel('Density')
plt.show()

# 인사이트
mean_price = np.mean(price)
median_price = np.median(price)

print(f"Mean Price: {mean_price}, Median Price: {median_price}")

if mean_price > median_price:
    print("주택 가격 분포가 오른쪽으로 치우쳐 있음을 의미")
elif mean_price < median_price:
    print("주택 가격 분포가 왼쪽으로 치우쳐 있음을 의미")
else:
    print("주택 가격이 고르게 분포되어 있음을 의미")
# Out:
# Mean Price: 475000.0, Median Price: 475000.0
# 주택 가격이 고르게 분포되어 있음을 의미

# %% [markdown]
# Q. 한 교육기관의 시험 점수 데이터가 다음과 같습니다:
#
# [55, 60, 65, 70, 75, 80, 85, 90, 95, 100].
#
# 시험 점수의 도수 분포표를 작성하고, 이를 통해 성적 분포에 대한 인사이트를 도출하세요.

# %%
scores = np.array([55, 60, 60, 65, 65, 65, 70, 70, 70, 70,  75, 75, 75,  80, 80, 80, 85, 85, 90, 95, 100])

# 도수분포표 생성

(unique, counts) = np.unique(scores, return_counts = True)
frequency_table = np.asarray((unique, counts)).T
print(frequency_table)

# 인사이트 해석

print("시험 점수의 도수 분포표를 통해 성적이 고르게 분포되어 있음을 확인할 수 있다")
# Out:
# [[ 55   1]
#  [ 60   2]
#  [ 65   3]
#  [ 70   4]
#  [ 75   3]
#  [ 80   3]
#  [ 85   2]
#  [ 90   1]
#  [ 95   1]
#  [100   1]]
# 시험 점수의 도수 분포표를 통해 성적이 고르게 분포되어 있음을 확인할 수 있다

# %% [markdown]
# Q. 한 회사의 연구개발(R&D) 투자 비용과 연간 수익 데이터가 각각 다음과 같습니다:
#
# 투자 비용 [100, 200, 300, 400, 500] (단위: 천 달러),
#
# 연간 수익 [200, 400, 600, 800, 1000] (단위: 천 달러).
#
# 추세선이 있는 산점도를 그려 투자 비용과 연간 수익 간의 관계를 시각화하고, 인사이트를 도출하세요.

# %%
rnd_investment = np.array([100, 200, 300, 400, 500])
annual_revenue = np.array([200, 400, 600, 800, 1000])

plt.scatter(rnd_investment, annual_revenue)
m, b = np.polyfit(rnd_investment, annual_revenue,1) # 기울기 , 절편
plt.title('Scatter plot with trend line')
plt.xlabel('R&D imvestment (thousand dollars)')
plt.ylabel('annual_revenue (thousand dollars)')
plt.show()

correlation = np.corrcoef(rnd_investment, annual_revenue)[0,1]
print(f"correlation coefficient: {correlation}")

if correlation > 0.7:
    print("R&D 투자와 연간 수익간에 강한 양의 상관관계")
else:
    print("R&D 투자와 연간 수익간에 상관관계가 약하거나 없음")
# Out:
# correlation coefficient: 0.9999999999999998
# R&D 투자와 연간 수익간에 강한 양의 상관관계
